# %% [markdown]
# <a href="https://colab.research.google.com/github/jaydengonzal2021/Statistics/blob/main/Jayden_GStats_Lab_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import urllib.request

# %%
url = "https://raw.githubusercontent.com/jaydengonzal2021/Statistics/main/cereal_data.csv"

# %%
urllib.request.urlretrieve(url,'cereal_data.csv')
# Out:
# ('cereal_data.csv', <http.client.HTTPMessage at 0x7f2c7d2bedd0>)

# %%
cereal_data = pd.read_csv('cereal_data.csv')

# %%
cereal_data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
#
# [77 rows x 16 columns]

# %%
cereal_data["sugars"]
# Out:
# 0      6
# 1      8
# 2      5
# 3      0
# 4      8
#       ..
# 72     3
# 73    12
# 74     3
# 75     3
# 76     8
# Name: sugars, Length: 77, dtype: int64

# %%
cereal_data[["sugars","calories"]]
# Out:
#     sugars  calories
# 0        6        70
# 1        8       120
# 2        5        70
# 3        0        50
# 4        8       110
# ..     ...       ...
# 72       3       110
# 73      12       110
# 74       3       100
# 75       3       100
# 76       8       110
#
# [77 rows x 2 columns]

# %%
cereal_data["sugars"].mean()
# Out:
# 6.922077922077922

# %%
cereal_data[["sugars","calories"]].mean()
# Out:
# sugars        6.922078
# calories    106.883117
# dtype: float64

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["calories"]],'.')

# %%
x = cereal_data[["sugars"]]
y = cereal_data[["calories"]]

plt.plot(x,y,'.')

# %%
x = cereal_data[["sugars"]]
y = cereal_data[["calories"]]

plt.plot(x,y,'.')
plt.xlabel("sugars")
plt.ylabel("calories")
plt.title("Sugars vs Calories")
# Out:
# Text(0.5, 1.0, 'Sugars vs Calories')

# %%
x = cereal_data[["fat"]]
y = cereal_data[["calories"]]

plt.plot(x,y,'.')
plt.xlabel("fat")
plt.ylabel("calories")
plt.title("Fat vs Calories")
# Out:
# Text(0.5, 1.0, 'Fat vs Calories')

# %%
x = cereal_data[["protein"]]
y = cereal_data[["rating"]]

plt.plot(x,y,'.')
plt.xlabel("protein")
plt.ylabel("rating")
plt.title("protein vs rating")
# Out:
# Text(0.5, 1.0, 'protein vs rating')

# %%
x = cereal_data[["protein"]]
y = cereal_data[["rating"]]

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()

# %%
linear_regressor.fit(x,y)
y_pred = linear_regressor.predict(x)

# %%
plt.plot (x,y,'.')
plt.plot(x,y_pred, color='red')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,50)

# %%
noise = 10 * np.random.randn(50,)

# %%
y = 3 * x + 7 + noise

# %%
plt.plot(x,y,'.');

# %%
m_guess = 1
b_guess = 1

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
m_guess = 5
b_guess = 15

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
m_guess = 3
b_guess = 7

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
loss = np.sum((y_guess - y)**2)

# %%
loss
# Out:
# 5766.792884729483

# %%
for m_guess in np.linspace(-10,10,10):
    print(m_guess)
# Out:
# -10.0
# -7.777777777777778
# -5.555555555555555
# -3.333333333333333
# -1.1111111111111107
# 1.1111111111111107
# 3.333333333333334
# 5.555555555555557
# 7.777777777777779
# 10.0

# %%
for m_guess in np.linspace(-10,10,10):
    for b_guess in np.linspace(-10,10,10):
        
        y_guess = m_guess * x + b_guess

        plt.plot(x,y_guess,'r.');
        plt.plot(x,y,'g.');
        plt.show()

        loss = np.sum((y_guess - y)**2)

        print(loss,m_guess,b_guess)
# Out:
# 447593.4575970144 -10.0 -10.0
# 429189.17799888353 -10.0 -7.777777777777778
# 411278.7255612467 -10.0 -5.555555555555555
# 393862.1002841035 -10.0 -3.333333333333333
# 376939.30216745427 -10.0 -1.1111111111111107
# 360510.33121129876 -10.0 1.1111111111111107
# 344575.1874156372 -10.0 3.333333333333334
# 329133.8707804693 -10.0 5.555555555555557
# 314186.3813057953 -10.0 7.777777777777779
# 299732.7189916152 -10.0 10.0
# 334773.56059839664 -7.777777777777778 -10.0
# 318838.4168027351 -7.777777777777778 -7.777777777777778
# 303397.10016756726 -7.777777777777778 -5.555555555555555
# 288449.6106928933 -7.777777777777778 -3.333333333333333
# 273995.94837871316 -7.777777777777778 -1.1111111111111107
# 260036.1132250268 -7.777777777777778 1.1111111111111107
# 246570.10523183426 -7.777777777777778 3.333333333333334
# 233597.92439913558 -7.777777777777778 5.555555555555557
# 221119.57072693077 -7.777777777777778 7.777777777777779
# 209135.04421521974 -7.777777777777778 10.0
# 238582.53737150997 -5.555555555555555 -10.0
# 225116.52937831747 -5.555555555555555 -7.777777777777778
# 212144.3485456188 -5.555555555555555 -5.555555555555555
# 199665.99487341393 -5.555555555555555 -3.333333333333333
# 187681.4683617029 -5.555555555555555 -1.1111111111111107
# 176190.76901048573 -5.555555555555555 1.1111111111111107
# 165193.89681976233 -5.555555555555555 3.333333333333334
# 154690.85178953278 -5.555555555555555 5.555555555555557
# 144681.6339197971 -5.555555555555555 7.777777777777779
# 135166.24321055523 -5.555555555555555 10.0
# 159020.3879163541 -3.333333333333333 -10.0
# 148023.5157256308 -3.333333333333333 -7.777777777777778
# 137520.47069540125 -3.333333333333333 -5.555555555555555
# 127511.25282566554 -3.333333333333333 -3.333333333333333
# 117995.86211642364 -3.333333333333333 -1.1111111111111107
# 108974.29856767556 -3.333333333333333 1.1111111111111107
# 100446.56217942135 -3.333333333333333 3.333333333333334
# 92412.65295166094 -3.333333333333333 5.555555555555557
# 84872.57088439436 -3.333333333333333 7.777777777777779
# 77826.31597762162 -3.333333333333333 10.0
# 96087.11223292924 -1.1111111111111107 -10.0
# 87559.375844675 -1.1111111111111107 -7.777777777777778
# 79525.46661691461 -1.1111111111111107 -5.555555555555555
# 71985.38454964804 -1.1111111111111107 -3.333333333333333
# 64939.129642875276 -1.1111111111111107 -1.1111111111111107
# 58386.701896596365 -1.1111111111111107 1.1111111111111107
# 52328.10131081126 -1.1111111111111107 3.333333333333334
# 46763.32788551999 -1.1111111111111107 5.555555555555557
# 41692.381620722546 -1.1111111111111107 7.777777777777779
# 37115.26251641894 -1.1111111111111107 10.0
# 49782.710321235274 1.1111111111111107 -10.0
# 43724.10973545017 1.1111111111111107 -7.777777777777778
# 38159.3363101589 1.1111111111111107 -5.555555555555555
# 33088.390045361455 1.1111111111111107 -3.333333333333333
# 28511.270941057843 1.1111111111111107 -1.1111111111111107
# 24427.978997248058 1.1111111111111107 1.1111111111111107
# 20838.514213932096 1.1111111111111107 3.333333333333334
# 17742.87659110996 1.1111111111111107 5.555555555555557
# 15141.066128781655 1.1111111111111107 7.777777777777779
# 13033.082826947177 1.1111111111111107 10.0
# 20107.182181272183 3.333333333333334 -10.0
# 16517.71739795622 3.333333333333334 -7.777777777777778
# 13422.079775134087 3.333333333333334 -5.555555555555555
# 10820.269312805784 3.333333333333334 -3.333333333333333
# 8712.286010971304 3.333333333333334 -1.1111111111111107
# 7098.129869630654 3.333333333333334 1.1111111111111107
# 5977.80088878383 3.333333333333334 3.333333333333334
# 5351.299068430833 3.333333333333334 5.555555555555557
# 5218.6244085716635 3.333333333333334 7.777777777777779
# 5579.776909206323 3.333333333333334 10.0
# 7060.52781304002 5.555555555555557 -10.0
# 5940.1988321931985 5.555555555555557 -7.777777777777778
# 5313.697011840203 5.555555555555557 -5.555555555555555
# 5181.022351981033 5.555555555555557 -3.333333333333333
# 5542.174852615695 5.555555555555557 -1.1111111111111107
# 6397.154513744179 5.555555555555557 1.1111111111111107
# 7745.9613353664945 5.555555555555557 3.333333333333334
# 9588.595317482635 5.555555555555557 5.555555555555557
# 11925.056460092603 5.555555555555557 7.777777777777779
# 14755.344763196395 5.555555555555557 10.0
# 10642.747216538784 7.777777777777779 -10.0
# 11991.554038161097 7.777777777777779 -7.777777777777778
# 13834.188020277235 7.777777777777779 -5.555555555555555
# 16170.649162887205 7.777777777777779 -3.333333333333333
# 19000.937465990995 7.777777777777779 -1.1111111111111107
# 22325.052929588623 7.777777777777779 1.1111111111111107
# 26142.995553680066 7.777777777777779 3.333333333333334
# 30454.76533826534 7.777777777777779 5.555555555555557
# 35260.36228334445 7.777777777777779 7.777777777777779
# 40559.786388917375 7.777777777777779 10.0
# 30853.84039176845 10.0 -10.0
# 34671.78301585991 10.0 -7.777777777777778
# 38983.55280044518 10.0 -5.555555555555555
# 43789.149745524286 10.0 -3.333333333333333
# 49088.5738510972 10.0 -1.1111111111111107
# 54881.82511716397 10.0 1.1111111111111107
# 61168.90354372453 10.0 3.333333333333334
# 67949.80913077897 10.0 5.555555555555557
# 75224.5418783272 10.0 7.777777777777779
# 82993.10178636925 10.0 10.0

# %%
best_loss = 100000
best_m = 0
best_b = 0 

for m_guess in np.linspace(-10,10,20):
    for b_guess in np.linspace(-10,10,20):
        
        y_guess = m_guess * x + b_guess

        loss = np.sum((y_guess - y)**2)

        if loss < best_loss:
            
            best_loss = loss
            best_m = m_guess
            best_b = b_guess 

